# %%
print ("All code related to data_protectionn 2")
# Out:
# All code related to data_protectionn 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
print ("it is working fine now")
# Out:
# it is working fine now

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
#
# git log <br>
# Enter: :wq               to come out of the editor <br>
# ![image-2.png](attachment:image-2.png)
#
# git log --online <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# use below command to revert already commited change (make sure we need to revert before it is pushed to git repo)
#
#
# git revert HEAD   → Reverts the project to the previously committed version

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# git revert --- is for reverting to previous 1 commit.<br>
# git reset ---- is for reveting to previous 3 or 4 commits or to the main branch.<br>
# by using 'git revert' ot 'git reset', we may loose previous commit id's.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
