# %%
print ("All code related to data_protection 2")
# Out:
# All code related to data_protection 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print ("it is working fine now")
# Out:
# it is working fine now
