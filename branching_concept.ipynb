# %% [markdown]
# to check you are in which branch
# >git branch
#
# ![image.png](attachment:image.png)
#
# to create new branch
# >git checkout -b feature_v1
#
# ![image-2.png](attachment:image-2.png)
#
#
# to cross check you are in which branch now
# >git branch
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# pushing 1 modefied file and 1 newly created file <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# >Feature banch -- will contain all the file which are there in main branch along with the new file<br>
#
# # Merging the feature branch to main banch
# >click on compare & Pull request <br>
# ![image.png](attachment:image.png)
#
# >click on create pull request<br>
# ![image-2.png](attachment:image-2.png)
#
# >add final review & submit <br>
# ![image-3.png](attachment:image-3.png)
#
# >click on merge pull request
# ![image-4.png](attachment:image-4.png)
#
# >Pull request was successull. Now if not required delete the feature branch <br>
# ![image-5.png](attachment:image-5.png)
